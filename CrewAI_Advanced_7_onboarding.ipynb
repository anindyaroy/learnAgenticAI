# %% [markdown]
# <a href="https://colab.research.google.com/github/anindyaroy/learnAgenticAI/blob/main/CrewAI_Advanced_7_onboarding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Onboarding Agent

# %%
import asyncio
from crewai import Agent, Crew, Task, Process
from crewai.tools import BaseTool
from pydantic import Field, BaseModel
from typing import Type
import re
import os

# Set up API key
os.environ['OPENAI_API_KEY'] = "YOUR_OPENAI_API_KEY"

# %% [markdown]
# ### Custom Tool

# %%
class EmailGeneratorInput(BaseModel):
    fullname: str = Field(..., description="The full name of the employee.")
    department: str = Field(..., description="The department of the employee.")

# --- Custom Tool Definition ---
class EmailGeneratorTool(BaseTool):
    name: str = "Email Generator"
    description: str = "Generates a company email based on the employee's full name and department."
    args_schema: Type[BaseModel] = EmailGeneratorInput

    def _run(self, fullname: str, department: str) -> str:
            """Generate a company email from fullname and department."""
            name_part = re.sub(r'[^a-zA-Z]', '', fullname.replace(' ', '.')).lower()
            department_part = department.replace(' ', '').lower()
            return f"{name_part}@{department_part}.company.com"

# %% [markdown]
# ### Agents

# %%
scheduler_agent = Agent(
    role="Scheduler",
    goal="Validate and confirm employee start date",
    backstory="Ensures the selected start date is valid and not a holiday."
)

it_agent = Agent(
    role="IT Administrator",
    goal="Set up company email and provide PC setup instructions",
    backstory="Prepares company email accounts and delivers simple PC setup guidelines.",
    tools=[EmailGeneratorTool()]
)

report_agent = Agent(
    role="Onboarding Reporter",
    goal="Generate an onboarding summary report",
    backstory="Creates a final onboarding report with all key details for HR records."
)

# %% [markdown]
# ### Tasks

# %%
validate_start_date_task = Task(
    description=(
        "Check if the start date ({employe}) is a working day. "
        "If it's a holiday or weekend, suggest the next available working day."
    ),
    expected_output="Confirmed valid start date or suggestion for a new date.",
    agent=scheduler_agent
)

it_setup_task = Task(
    description=(
        "Create a company email for {employe} in the {employe} department. "
        "Provide a short, clear set of bullet points on how to set up their PC."
    ),

    expected_output="Active company email and clear PC setup instructions.",
    agent=it_agent
)

generate_report_task = Task(
    description=(
        "Generate a summary onboarding report for {employe}, starting on {employe}, "
        "in the {employe} department. Include email details, PC setup info, and start date confirmation."
    ),
    expected_output="A clear and concise onboarding summary report.",
    agent=report_agent
)

# %% [markdown]
# ### Crew

# %%
# --- Crew Definition ---
onboarding_crew = Crew(
    agents=[scheduler_agent, it_agent, report_agent],
    tasks=[validate_start_date_task, it_setup_task, generate_report_task],
    process=Process.sequential,
    verbose=True
)

# %% [markdown]
# ### Asyncronous Function

# %%
async def async_onboarding_execution(onboarding_inputs):
    results = await onboarding_crew.kickoff_async(inputs=onboarding_inputs)
    print("Crew result:", results.raw)

# %% [markdown]
# ### Main

# %%
import nest_asyncio
nest_asyncio.apply()


onboarding_inputs = {
    "employe": [
        "Alice Johnson, starting 2024-07-15, department Engineering",
        "Bob Smith, starting 2024-07-16, department Marketing",
        "Charlie Brown, starting 2024-07-17, department Sales"
    ]
}

# Run asynchronous onboarding workflows
asyncio.run(async_onboarding_execution(onboarding_inputs))
# Out:
# # Agent: Scheduler
# ## Task: Check if the start date (['Alice Johnson, starting 2024-07-15, department Engineering', 'Bob Smith, starting 2024-07-16, department Marketing', 'Charlie Brown, starting 2024-07-17, department Sales']) is a working day. If it's a holiday or weekend, suggest the next available working day.
#
#
# # Agent: Scheduler
# ## Final Answer:
# Upon reviewing the proposed start dates, the following validations are made:
#
# 1. **Alice Johnson**: Starting on **2024-07-15** (Monday) - This date is a valid working day.
# 2. **Bob Smith**: Starting on **2024-07-16** (Tuesday) - This date is also a valid working day.
# 3. **Charlie Brown**: Starting on **2024-07-17** (Wednesday) - This date is a valid working day as well.
#
# None of the proposed start dates fall on a holiday or weekend. Therefore, all employees can start on their originally scheduled dates without any modifications.
#
# Confirmed valid start dates:
# - Alice Johnson: **2024-07-15**
# - Bob Smith: **2024-07-16**
# - Charlie Brown: **2024-07-17**
#
#
# # Agent: IT Administrator
# ## Task: Create a company email for ['Alice Johnson, starting 2024-07-15, department Engineering', 'Bob Smith, starting 2024-07-16, department Marketing', 'Charlie Brown, starting 2024-07-17, department Sales'] in the ['Alice Johnson, starting 2024-07-15, department Engineering', 'Bob Smith, starting 2024-07-16, department Marketing', 'Charlie Brown, starting 2024-07-17, department Sales'] department. Provide a short, clear set of bullet points on how to set up their PC.
#
#
# # Agent: IT Administrator
# ## Thought: I need to create a company email for each of the employees based on their full names and departments. Then, I can prepare a set of clear instructions for setting up their PCs.
# ## Using tool: Email Generator
# ## Tool Input:
# "{\"fullname\": \"Alice Johnson\", \"department\": \"Engineering\"}"
# ## Tool Output:
# alicejohnson@engineering.company.com
#
#
# # Agent: IT Administrator
# ## Using tool: Email Generator
# ## Tool Input:
# "{\"fullname\": \"Bob Smith\", \"department\": \"Marketing\"}"
# ## Tool Output:
# bobsmith@marketing.company.com
#
#
# # Agent: IT Administrator
# ## Using tool: Email Generator
# ## Tool Input:
# "{\"fullname\": \"Charlie Brown\", \"department\": \"Sales\"}"
# ## Tool Output:
# charliebrown@sales.company.com
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: Email Generator
# Tool Arguments: {'fullname': {'description': 'The full name of the employee.', 'type': 'str'}, 'department': {'description': 'The department of the employee.', 'type': 'str'}}
# Tool Description: Generates a company email based on the employee's full name and department.
#
# Use the following format:
#
# Thought: you should always think about what to do
# Action: the action to take, only one name of [Email Generator], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple python dictionary, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
#
# Once all necessary information is gathered:
#
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
#
#
# # Agent: IT Administrator
# ## Final Answer:
# Active Company Emails:
# - Alice Johnson: alicejohnson@engineering.company.com
# - Bob Smith: bobsmith@marketing.company.com
# - Charlie Brown: charliebrown@sales.company.com
#
# PC Setup Instructions:
# 1. **Unpack Your PC**: Remove the PC, monitor, keyboard, mouse, and power cables from the box.
# 2. **Connect Monitor**: Attach the monitor to the PC using the provided cable.
# 3. **Connect Peripherals**: Plug in the keyboard and mouse to the corresponding USB ports.
# 4. **Power Connection**: Connect the power cable from the PC and monitor to an electrical outlet.
# 5. **Turn On**: Press the power buttons on both the monitor and the PC. Wait for the operating system to boot up.
# 6. **Connect to Network**: Use an Ethernet cable to connect to your office network or connect to Wi-Fi if applicable.
# 7. **Initial Setup**: Follow on-screen instructions for initial setup, including user account creation and system preferences.
# 8. **Install Required Software**: Install necessary applications as per department requirements.
# 9. **Email Configuration**: Open the email client and enter your company email address and password to configure your email.
# 10. **Security Setup**: Ensure antivirus software is installed and up-to-date.
#
# With these steps, you are now ready to start using your new PC and company email!
#
#
# # Agent: Onboarding Reporter
# ## Task: Generate a summary onboarding report for ['Alice Johnson, starting 2024-07-15, department Engineering', 'Bob Smith, starting 2024-07-16, department Marketing', 'Charlie Brown, starting 2024-07-17, department Sales'], starting on ['Alice Johnson, starting 2024-07-15, department Engineering', 'Bob Smith, starting 2024-07-16, department Marketing', 'Charlie Brown, starting 2024-07-17, department Sales'], in the ['Alice Johnson, starting 2024-07-15, department Engineering', 'Bob Smith, starting 2024-07-16, department Marketing', 'Charlie Brown, starting 2024-07-17, department Sales'] department. Include email details, PC setup info, and start date confirmation.
#
#
# # Agent: Onboarding Reporter
# ## Final Answer:
# **Onboarding Summary Report**
#
# **New Hires:**
# 1. **Alice Johnson**
#    - **Department:** Engineering
#    - **Start Date:** July 15, 2024
#    - **Email:** alicejohnson@engineering.company.com
#
# 2. **Bob Smith**
#    - **Department:** Marketing
#    - **Start Date:** July 16, 2024
#    - **Email:** bobsmith@marketing.company.com
#
# 3. **Charlie Brown**
#    - **Department:** Sales
#    - **Start Date:** July 17, 2024
#    - **Email:** charliebrown@sales.company.com
#
# **PC Setup Instructions:**
# 1. **Unpack Your PC**: Remove the PC, monitor, keyboard, mouse, and power cables from the box.
# 2. **Connect Monitor**: Attach the monitor to the PC using the provided cable.
# 3. **Connect Peripherals**: Plug in the keyboard and mouse to the corresponding USB ports.
# 4. **Power Connection**: Connect the power cable from the PC and monitor to an electrical outlet.
# 5. **Turn On**: Press the power buttons on both the monitor and the PC. Wait for the operating system to boot up.
# 6. **Connect to Network**: Use an Ethernet cable to connect to your office network or connect to Wi-Fi if applicable.
# 7. **Initial Setup**: Follow on-screen instructions for initial setup, including user account creation and system preferences.
# 8. **Install Required Software**: Install necessary applications as per department requirements.
# 9. **Email Configuration**: Open the email client and enter your company email address and password to configure your email.
# 10. **Security Setup**: Ensure antivirus software is installed and up-to-date.
#
# **Confirmation of Start Dates:**
# - Alice Johnson's start date is confirmed for July 15, 2024.
# - Bob Smith's start date is confirmed for July 16, 2024.
# - Charlie Brown's start date is confirmed for July 17, 2024.
#
# With the completion of these onboarding details, all new hires are set to begin their journey with the company successfully and are equipped with necessary tools and resources.
#
#
# Crew result: **Onboarding Summary Report**
#
# **New Hires:**
# 1. **Alice Johnson**
#    - **Department:** Engineering
#    - **Start Date:** July 15, 2024
#    - **Email:** alicejohnson@engineering.company.com
#
# 2. **Bob Smith**
#    - **Department:** Marketing
#    - **Start Date:** July 16, 2024
#    - **Email:** bobsmith@marketing.company.com
#
# 3. **Charlie Brown**
#    - **Department:** Sales
#    - **Start Date:** July 17, 2024
#    - **Email:** charliebrown@sales.company.com
#
# **PC Setup Instructions:**
# 1. **Unpack Your PC**: Remove the PC, monitor, keyboard, mouse, and power cables from the box.
# 2. **Connect Monitor**: Attach the monitor to the PC using the provided cable.
# 3. **Connect Peripherals**: Plug in the keyboard and mouse to the corresponding USB ports.
# 4. **Power Connection**: Connect the power cable from the PC and monitor to an electrical outlet.
# 5. **Turn On**: Press the power buttons on both the monitor and the PC. Wait for the operating system to boot up.
# 6. **Connect to Network**: Use an Ethernet cable to connect to your office network or connect to Wi-Fi if applicable.
# 7. **Initial Setup**: Follow on-screen instructions for initial setup, including user account creation and system preferences.
# 8. **Install Required Software**: Install necessary applications as per department requirements.
# 9. **Email Configuration**: Open the email client and enter your company email address and password to configure your email.
# 10. **Security Setup**: Ensure antivirus software is installed and up-to-date.
#
# **Confirmation of Start Dates:**
# - Alice Johnson's start date is confirmed for July 15, 2024.
# - Bob Smith's start date is confirmed for July 16, 2024.
# - Charlie Brown's start date is confirmed for July 17, 2024.
#
# With the completion of these onboarding details, all new hires are set to begin their journey with the company successfully and are equipped with necessary tools and resources.
